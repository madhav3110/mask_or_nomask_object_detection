# %% [markdown]
# # **AI MAJOR PROJECT - DETECTING MASK OR NO MASK**

# %%
cd /content/drive/MyDrive       # changing to the specified directory
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ultralytics/yolov5        # cloning yolov5 software from github.com
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
cd yolov5
# Out:
# /content/drive/MyDrive/yolov5

# %%
ls
# Out:
# CONTRIBUTING.md  export.py   __pycache__/      setup.cfg       val.py
# data/            hubconf.py  README.md         train.py        yolov5l.pt
# detect.py        LICENSE     requirements.txt  tutorial.ipynb  yolov5s.pt
# Dockerfile       models/     runs/             utils/          yolov5x.pt

# %%
# %pip install -qr requirements.txt       # installing required folders of yolov5

# %%
ls
# Out:
# CONTRIBUTING.md  export.py   __pycache__/      setup.cfg       val.py
# data/            hubconf.py  README.md         train.py        yolov5l.pt
# detect.py        LICENSE     requirements.txt  tutorial.ipynb  yolov5s.pt
# Dockerfile       models/     runs/             utils/          yolov5x.pt

# %%
import torch            # importing torch module
from IPython.display import Image, clear_output
clear_output()

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla K80)

# %%
# training the model
! python train.py --img 640 --batch 16 --epochs 50 --data custom.yaml --weights yolov5s.pt --nosave --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 1), reused 2 (delta 1), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/ultralytics/yolov5
#    7473f0f..09d1703  master     -> origin/master
# ...

# %% [markdown]
# **TESTING THE TRAINED MODEL**

# %%
# test_1
# !python detect.py --weights runs/train/exp4//weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/test/test_1.jpg
# Out:
# detect: weights=['runs/train/exp4//weights/last.pt'], source=/content/drive/MyDrive/test/test_1.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-7 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/test/test_1.jpg: 640x448 1 no_mask, Done. (0.035s)
# Speed: 0.5ms pre-process, 34.9ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp29

# %%
# printing the output of test_1
Image(filename='/content/drive/MyDrive/yolov5/runs/detect/exp29/test_1.jpg')

# %%
# test_2
# !python detect.py --weights runs/train/exp4/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/test/test_2.jpg
# Out:
# detect: weights=['runs/train/exp4/weights/last.pt'], source=/content/drive/MyDrive/test/test_2.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-7 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/test/test_2.jpg: 480x640 1 mask, Done. (0.032s)
# Speed: 0.5ms pre-process, 31.7ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp30

# %%
# printing the output of test_2
Image(filename='/content/drive/MyDrive/yolov5/runs/detect/exp30/test_2.jpg')

# %%
# test_3
# !python detect.py --weights runs/train/exp4/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/test/test_3.jpg
# Out:
# detect: weights=['runs/train/exp4/weights/last.pt'], source=/content/drive/MyDrive/test/test_3.jpg, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-7 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/test/test_3.jpg: 448x640 1 no_mask, Done. (0.030s)
# Speed: 0.5ms pre-process, 30.1ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp31

# %%
# printing the output of test_3
Image(filename='/content/drive/MyDrive/yolov5/runs/detect/exp31/test_3.jpg')

# %%
# test_4
# !python detect.py --weights runs/train/exp4/weights/last.pt --img 1280 --conf 0.25 --source /content/drive/MyDrive/test/test_4.jpg
# Out:
# detect: weights=['runs/train/exp4/weights/last.pt'], source=/content/drive/MyDrive/test/test_4.jpg, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-7 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/test/test_4.jpg: 736x1280 2 masks, 3 no_masks, Done. (0.062s)
# Speed: 1.1ms pre-process, 61.8ms inference, 1.9ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp32

# %%
# printing the output of test_4
Image(filename='/content/drive/MyDrive/yolov5/runs/detect/exp32/test_4.jpg')

# %%
# test_5
# !python detect.py --weights runs/train/exp4/weights/last.pt --img 1280 --conf 0.25 --source /content/drive/MyDrive/test/test_5.jpg
# Out:
# detect: weights=['runs/train/exp4/weights/last.pt'], source=/content/drive/MyDrive/test/test_5.jpg, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-11-7 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/test/test_5.jpg: 768x1280 2 masks, Done. (0.061s)
# Speed: 1.3ms pre-process, 61.5ms inference, 1.9ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp33

# %%
# printing the output of test_5
Image(filename='/content/drive/MyDrive/yolov5/runs/detect/exp33/test_5.jpg')

# %% [markdown]
# DONE BY :
#
# **1. Rahul Krishna Turaga (rahul123138@gmail.com)**
#
# **2. Siddhi Venkata Sai Karthik Veeranki (siddhi.karthik.20033@iitgoa.ac.in)**
#
# **3. Koduri Sai Madhav (madhavchowdary33@gmail.com)**
#
# **4. Daivala Govardhan Reddy (govardhand0681@gmail.com)**
#
# **5. Jasti Sudheer (sudheerjasti2002@gmail.com)**
#
# Note : This project has been done successfully by the above five interns belonging to AI-09-BML4.
# No other intern (except above) is responsible for this project work.
